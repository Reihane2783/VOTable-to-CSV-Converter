# %%
from astropy.io.votable import parse_single_table
import pandas as pd

table = parse_single_table(r"C:\Users\Lenovo\Desktop\nojum\11.vot")

df = table.to_table().to_pandas()
print(df)
df.to_csv(r"C:\Users\Lenovo\Desktop\nojum\11.csv",index=False)
# Out:
#       _RAB1950   _DEB1950   recno     Seq      Name    ID  \
# 0   118.294564 -39.490753  444259  444258  NGC_2477  4578
# 1   117.709714 -39.349473  444260  444259  NGC_2477  4578
# 2   117.910943 -39.474524  444261  444260  NGC_2477  4578
# 3   118.074879 -39.394745  444262  444261  NGC_2477  4578
# 4   118.280575 -39.357718  444263  444262  NGC_2477  4578
# 5   118.184152 -39.312890  444264  444263  NGC_2477  4578
# 6   118.154201 -39.316721  444265  444264  NGC_2477  4578
# 7   118.114643 -39.289227  444266  444265  NGC_2477  4578
# 8   118.211206 -39.155446  444267  444266  NGC_2477  4578
# 9   117.732937 -39.349708  444268  444267  NGC_2477  4578
# 10  117.719403 -39.336220  444269  444268  NGC_2477  4578
# 11  117.796887 -39.273355  444270  444269  NGC_2477  4578
# 12  117.924677 -39.240944  444271  444270  NGC_2477  4578
# 13  118.151209 -39.168289  444272  444271  NGC_2477  4578
# 14  118.129667 -39.156262  444273  444272  NGC_2477  4578
# ...
